# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('/home/bz/korean.txt')

# %%
data.head()
#data.iloc[0].char
# Out:
#   char    ord     num
# 0    다  45796  100263
# 1    이  51060   87957
# 2    는  45716   70416
# 3    리  47532   66529
# 4    가  44032   64448

# %%
_ = plt.plot(sorted(data.ord))

# %%
_ = plt.boxplot(data.ord)

# %%
_ = plt.hist(data.ord, 100)

# %%
plt.scatter(data.ord, data.num)
_ = plt.vlines(43000, min(data.num), max(data.num))
_ = plt.vlines(57000, min(data.num), max(data.num))

# %%
sub = data.loc[(data.ord > 43000) & (data.ord < 57000)]
sub.shape
#data.num
#data.num > 43000
# Out:
# (1781, 3)

# %%
plt.figure(figsize=(12, 8))
plt.scatter(sub.ord, sub.num)

# %%
sub2 = sub.loc[sub.num > 1000]
print(sub2.shape)

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(1,1,1)
plt.scatter(sub2.ord, sub2.num)
ax.set_yscale('log')
# Out:
# (360, 3)

# %%
sub2.char
# Out:
# 0      다
# 1      이
# 2      는
# 3      리
# 4      가
# 5      그
# 6      을
# 7      지
# 8      에
# 9      고
# 10     어
# 11     해
# 12     하
# 13     로
# 14     아
# 15     들
# 16     를
# 17     의
# 18     서
# 19     도
# 20     었
# 21     있
# 22     은
# 23     게
# 24     나
# 25     말
# 26     기
# 27     했
# 28     한
# 29     자
#       ..
# 330    옆
# 331    봐
# 332    플
# 333    럽
# 334    냈
# 335    밖
# 336    황
# 337    꺼
# 338    숙
# 339    벽
# 340    놀
# 341    닥
# 342    뿐
# 343    창
# 344    떤
# 345    매
# 346    배
# 347    격
# 348    둥
# 349    될
# 350    틀
# 351    득
# 352    험
# 353    랐
# 354    냐
# 355    등
# 356    림
# 357    귀
# 358    렀
# 359    뜨
# Name: char, dtype: object
